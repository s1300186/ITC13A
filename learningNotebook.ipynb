# %% [markdown]
# <a href="https://colab.research.google.com/github/s1300186/ITC13A/blob/main/learningNotebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ITC13A

# %%
print("Hello World")
# Out:
# Hello World
